# %%
# Import Dependencies
import pandas as pd
import numpy as np
from citipy import citipy

# Import API
from config import weather_api_key

# Import Requests
import requests

# %%
# Create a set to hold random latitude and longitude combinations
lats = np.random.uniform(low=-100.000, high=100.000, size=2000)
lngs = np.random.uniform(low=-100.000, high=100.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Find the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)

# len(cities)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
count = 1

# Loop through the cities in the list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Percent Humidity": city_humidity,
                          "Percent Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | hofn
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | la paz
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | menongue
# Processing Record 11 of Set 1 | bengkulu
# Processing Record 12 of Set 1 | tucuman
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | cookeville
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | paamiut
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | ustye
# Processing Record 19 of Set 1 | talnakh
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | hithadhoo
# ...

# %%
# Create a Dataframe to hold the array of dictionaries
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Percent Humidity  \
# 0   Port Alfred      ZA -33.5906   26.8910     75.61                92
# 1  Punta Arenas      CL -53.1500  -70.9167     57.11                44
# 2          Hofn      IS  64.2539  -15.2082     24.37                69
# 3          Chuy      UY -33.6971  -53.4616     68.36                97
# 4        La Paz      BO -16.5000  -68.1500     55.38                71
# 5       Ushuaia      AR -54.8000  -68.3000     47.86                53
# 6      Tasiilaq      GL  65.6145  -37.6368      8.76                66
# 7          Lebu      CL -37.6167  -73.6500     67.35                61
# 8      Menongue      AO -14.6585   17.6910     63.64                94
# 9      Bengkulu      ID  -3.8004  102.2655     75.51                85
#
#    Percent Cloudiness  Wind Speed Current Weather Description
# 0                   5       12.91                   clear sky
# 1                  29       23.42            scattered clouds
# ...

# %%
# Open the output file
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Save the city_data as a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
